# %% [markdown]
# # Air Drag on Falling Cones

# %%
import numpy as np
data = np.loadtxt("cones.csv")

def model(p,x):
    return p[0] + p[1]*x

distance = 30
distance_sigma = 0.5/100 ## Don't know this value either

# Align with actual data columns

m = np.array(data[:,0])
# m_unc = //whatever it is//
m_sigma = np.array(data[:,1]) # Should be constant so replace this # np.full(len(data[:,0]), m_unc)
t1 = np.array(data[:,2])
t2 = np.array(data[:,3])
t3 = np.array(data[:,4])
t4 = np.array(data[:,5])
t5 = np.array(data[:,6])
t = (t1+t2+t3+t4+t5)/5
v = distance/t
vs = v**2
t_sigma = 0.2/5 ## Don't know what the value is
vs_sigma = np.sqrt((distance**2/t**4)*distance_sigma**2+(4*distance**4/t**6)*t_sigma**2)


x = m
y = vs
sigma_x = m_sigma
sigma_y = vs_sigma


bf = np.zeros((2,len(data3)))
bf[0,:] = x**0
bf[1,:] = x

A = np.zeros((2,2))
b = np.zeros(2)
for k in range(2):
    for j in range(2):
        A[k,j] = np.sum(bf[k,:]*bf[j,:]/sigma_y**2) 
    b[k] = np.sum(y*bf[k,:]/sigma_y**2)
              
A_inv = np.linalg.inv(A)
a = np.linalg.solve(A,b)

xx = np.linspace(0.04,0.18,1000) # Change

## VARS for coefficient

phi = 2.206
g = 9.81
p = 1.225
r = 0.1

###


grad = a[1]

C_d = (grad*8*np.pi*g)/(p*(r**2)*(phi**2))
print("C_d: "+str(C_d))


plt.rcdefaults()  # turn off xkcd
plt.figure()
plt.errorbar(x,y,sigma_y,sigma_x,fmt='.')
plt.plot(xx,model(a,xx),'r-')

plt.xlabel('Mass (m)')
plt.ylabel('Velocity Squared ($v^2$)')
